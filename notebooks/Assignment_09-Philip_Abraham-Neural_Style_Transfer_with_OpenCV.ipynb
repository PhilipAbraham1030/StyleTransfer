# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
import datajoint as dj

# %%
schema = dj.schema('testneural')

# %%
dj.Diagram(schema)

# %%
@schema
class Source(dj.Lookup):
    definition = """
    name : char(12)
    ---
    image_url : varchar(255)
    """
    
    contents = (
        ('mona', 'https://upload.wikimedia.org/wikipedia/commons/5/55/Mona_Lisa_headcrop.jpg'),
        ('starry', 'https://upload.wikimedia.org/wikipedia/commons/f/f2/VangoghStarry-night2.jpg')
    )

# %%
Source.drop()

# %%
import imageio
import cv2

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
import urllib.request

# %%
url = "https://media.giphy.com/media/lEfkfM3Xubvvq/giphy.gif"
fname = "tmp.gif"

## Read the gif from the web, save to the disk
imdata = urllib.request.urlopen(url).read()
imbytes = bytearray(imdata)
open(fname,"wb+").write(imdata)
# Out:
# 1121682

# %%
## Read the gif from disk to `RGB`s using `imageio.miread` 
gif = imageio.mimread(fname)
nums = len(gif)
print("Total {} frames in the gif!".format(nums))
# Out:
# Total 10 frames in the gif!

# %%
# convert form RGB to BGR 
imgs = [cv2.cvtColor(img, cv2.COLOR_RGB2BGR) for img in gif]

# %%
## Display the gif
image = cv2.imread(a)
cv2.imshow("gif", image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-27de41ab6550> in <module>
#       1 ## Display the gif
# ----> 2 image = cv2.imread(a)
#
# TypeError: Can't convert object of type 'numpy.ndarray' to 'str' for 'filename'

# %%
![ChessUrl]"https://media.giphy.com/media/lEfkfM3Xubvvq/giphy.gif"

# %%
import matplotlib.image as mpimg

# %%
img = mpimg.imread(fname)

# %%
plt.imshow(a)

# %%
from PIL import Image
import requests
import tempfile

def load_gif_url(url):
    with tempfile.NamedTemporaryFile(suffix=".gif") as f:
        f.write(requests.get(url).content)
        f.flush()
        img = Image.open(f.name)

    with tempfile.NamedTemporaryFile(suffix=".png") as f:
        img.save(f.name)
        f.flush()
        src = cv2.imread(f.name)

    assert src is not None and len(src), "Empty"

    return src

# %%
a=load_gif_url("https://media.giphy.com/media/lEfkfM3Xubvvq/giphy.gif")

# %%
plt.imshow(a)

# %%
cv2.imshow("gif", a)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
![](https://media.giphy.com/media/lEfkfM3Xubvvq/giphy.gif)
# Out:
# /usr/bin/sh: 1: Syntax error: word unexpected (expecting ")")

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
from IPython import display

# %%
url = "https://media.giphy.com/media/lEfkfM3Xubvvq/giphy.gif"
fname = "tmp.gif"

## Read the gif from the web, save to the disk
imdata = urllib.request.urlopen(url).read()

# %%
from pathlib import Path
gifPath = Path("https://media.giphy.com/media/lEfkfM3Xubvvq/giphy.gif")
# Display GIF in Jupyter, CoLab, IPython
with open(urllib.request.urlopen(url).read(),'rb') as f:
    display.Image(data=f.read(), format='png')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-a848f3f43170> in <module>
#       2 gifPath = Path("https://media.giphy.com/media/lEfkfM3Xubvvq/giphy.gif")
#       3 # Display GIF in Jupyter, CoLab, IPython
# ----> 4 with open(urllib.request.urlopen(url).read(),'rb') as f:
#       5     display.Image(data=f.read(), format='png')
#
# ValueError: embedded null byte
